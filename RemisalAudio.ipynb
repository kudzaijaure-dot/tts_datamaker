# %%
dataset_name = "Mugabe" #@param {type:"string"}
p_id = 'p505' #@param {type:"string"}
output_directory = "traineroutput" #@param {type:"string"}
upload_dir = "wav48_silence_trimmed/" + p_id + "/" #@param {type:"string"}
upload_dir = "/content/drive/MyDrive/" +dataset_name + '/' + upload_dir
silence_thresh = -40 #@param {type:"number"}
silence_dim = 300 #@param {type:"number"}

# %%
import shutil
shutil.rmtree("/content/drive/MyDrive/VCTK")

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
cd ../
# Out:
# /content

# %%
# !git clone https://github.com/kudzaijaure-dot/tts_datamaker.git
# Out:
# Cloning into 'tts_datamaker'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 92 (delta 48), reused 69 (delta 36), pack-reused 0
# Receiving objects: 100% (92/92), 1.15 MiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
cd tts_datamaker
# Out:
# /content/tts_datamaker

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 35.5 MB/s eta 0:00:00
# ...

# %%
# !cd main_audio && gdown https://drive.google.com/file/d/1pWbvRqo2Q3ftGUm_1OKcF46Q2BdZoFWm/view?usp=drive_link
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gz-Yptg8HmrOaLiIcKxHRs0OT5T7a1io
# To: /content/tts_datamaker/main_audio/SadghuruFinal.wav
# 100% 379M/379M [00:03<00:00, 105MB/s]

# %%
import os
print(os.getcwd())
# Out:
# /content/tts_datamaker

# %%
cd ../
# Out:
# /content

# %%
# !mkdir /content/drive/MyDrive/VCTK
# !mkdir drive/MyDrive/VCTK/txt
# !mkdir drive/MyDrive/VCTK/txt/$p_id/
# !mkdir drive/MyDrive/Mugabe
# !mkdir drive/MyDrive/Mugabe/wav48_silence_trimmed
# !mkdir drive/MyDrive/Mugabe/wav48_silence_trimmed/x

# %%
cd tts_datamaker
# Out:
# /content/tts_datamaker

# %%
from os import path
from pydub import AudioSegment

# files
src = "main_audio/mugababe.mp3"
dst = "main_audio/mugababe.wav"

# convert mp4 to wav
sound = AudioSegment.from_file(src,format="mp3")
sound.export(dst, format="wav")
# Out:
# <_io.BufferedRandom name='main_audio/mugababe.wav'>

# %%
import os
os.remove("main_audio/PLumumbaDataset.mp3")

# %%
from pydub import AudioSegment
from pydub.silence import split_on_silence

#reading from audio mp3 file
sound = AudioSegment.from_wav("main_audio/mugababe.wav")

# spliting audio files
audio_chunks = split_on_silence(sound, min_silence_len=silence_dim, silence_thresh=silence_thresh )
print(len(audio_chunks))
#loop is used to iterate over the output list !mkdir /content/tts_train_dir/karan/wavs

# %%
print(len())

# %%
for i, chunk in enumerate(audio_chunks):
  output_file1 = "/content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/" + p_id +"_{}_mic1.wav".format(str(i).zfill(3))
  output_file2 = "/content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/" + p_id +"_{}_mic2.wav".format(str(i).zfill(3))
  print("Exporting file", output_file1)
  print("Exporting file", output_file2)
  chunk.export(output_file1, format="wav")
  chunk.export(output_file2, format="wav")
# Out:
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_000_mic1.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_000_mic2.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_001_mic1.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_001_mic2.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_002_mic1.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_002_mic2.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_003_mic1.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_003_mic2.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_004_mic1.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_004_mic2.wav
# Exporting file /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_005_mic1.wav
# ...

# %%
from extract_text import text_extraction
output_folder_split="../drive/MyDrive/VCTK/wav48_silence_trimmed/x"

path_to_audio_split=output_folder_split
output_folder="../"
output_file= "metadata.txt"

et=text_extraction(path_to_audio_split)
et.extract(output_folder,output_file)
# Out:
# Extracted text from p502_000_mic1.wav
# Extracted text from p502_000_mic2.wav
# Extracted text from p502_001_mic1.wav
# Extracted text from p502_001_mic2.wav
# Extracted text from p502_002_mic1.wav
# Extracted text from p502_002_mic2.wav
# Extracted text from p502_003_mic1.wav
# Extracted text from p502_003_mic2.wav
# Could not extract from p502_004_mic1.wav
# Could not extract from p502_004_mic2.wav
# Extracted text from p502_005_mic1.wav
# Extracted text from p502_005_mic2.wav
# Extracted text from p502_006_mic1.wav
# Extracted text from p502_006_mic2.wav
# Extracted text from p502_007_mic1.wav
# Extracted text from p502_007_mic2.wav
# Extracted text from p502_008_mic1.wav
# Extracted text from p502_008_mic2.wav
# Extracted text from p502_009_mic1.wav
# Extracted text from p502_009_mic2.wav
# Extracted text from p502_010_mic1.wav
# Extracted text from p502_010_mic2.wav
# Extracted text from p502_011_mic1.wav
# Extracted text from p502_011_mic2.wav
# ...

# %%
import os, os.path
import glob

wavs = '/content/drive/MyDrive/'+ dataset_name + '/wav48_silence_trimmed/x/'
paths = glob.glob(os.path.join(wavs, '*.wav'))

print(len(paths))
# Out:
# 1450

# %%
cd ../
# Out:
# /content

# %%
# !pip install pyloudnorm
# !git clone https://github.com/xiph/rnnoise.git
# !sudo apt-get install curl autoconf automake libtool python-dev pkg-config sox ffmpeg
# %cd /content/rnnoise
# !sh autogen.sh
# !sh configure
# !make clean
# !make
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Cloning into 'rnnoise'...
# remote: Enumerating objects: 420, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 420 (delta 194), reused 192 (delta 192), pack-reused 201
# Receiving objects: 100% (420/420), 836.04 KiB | 12.67 MiB/s, done.
# Resolving deltas: 100% (221/221), done.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'python-dev-is-python2' instead of 'python-dev'
# autoconf is already the newest version (2.69-11.1).
# autoconf set to manually installed.
# automake is already the newest version (1:1.16.1-4ubuntu6).
# automake set to manually installed.
# pkg-config is already the newest version (0.29.1-0ubuntu4).
# curl is already the newest version (7.68.0-1ubuntu2.18).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content/rnnoise

# %%
import os, os.path
import glob

wavs = '/content/drive/MyDrive/'+ dataset_name + '/wav48_silence_trimmed/x/'
paths = glob.glob(os.path.join(wavs, '*.wav'))
for path in paths:
  new_path = str(path).replace("p500", "p501")
  os.rename(path, new_path)
  print(path)
# Out:
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_000_mic1.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_000_mic2.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_001_mic1.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_001_mic2.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_002_mic1.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_002_mic2.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_003_mic1.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_003_mic2.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_005_mic1.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_005_mic2.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_006_mic1.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_006_mic2.wav
# /content/drive/MyDrive/VCTK3/wav48_silence_trimmed/x/p501_007_mic1.wav
# ...

# %%
cd ../
# Out:
# /content

# %%
# !python /content/drive/MyDrive/rnnoise.py /content/VCTK/wav48_silence_trimmed/x
# Out:
# From: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_000_mic1.wav
# To: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/p502/p502_000_mic1.wav
#
# From: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_000_mic2.wav
# To: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/p502/p502_000_mic2.wav
#
# From: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_001_mic1.wav
# To: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/p502/p502_001_mic1.wav
#
# From: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_001_mic2.wav
# To: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/p502/p502_001_mic2.wav
#
# From: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_002_mic1.wav
# To: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/p502/p502_002_mic1.wav
#
# From: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/x/p502_002_mic2.wav
# To: /content/drive/MyDrive/VCTK/wav48_silence_trimmed/p502/p502_002_mic2.wav
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content/rnnoise

# %%
cd ../
# Out:
# /content

# %%
import shutil
shutil.rmtree('/content/drive/MyDrive/VCTK/wav48_silence_trimmed/x')

# %%
# %cd /content
# !sudo apt install sox
# !git clone https://github.com/openai/whisper.git
# !pip install git+https://github.com/openai/whisper.git
# Out:
# /content
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 sox
# 0 upgraded, 6 newly installed, 0 to remove and 23 not upgraded.
# Need to get 513 kB of archives.
# After this operation, 1,564 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [225 kB]
# ...

# %%
import whisper
import os, os.path
import glob
import pandas as pd

from pathlib import Path

wavs = upload_dir

model = whisper.load_model("medium.en")
paths = glob.glob(os.path.join(wavs, '*.wav'))
print(len(paths))

all_filenames = []
transcript_text = []
# with open('/content/drive/MyDrive/'+ dataset_name +'/metadata.csv', 'w', encoding='utf-8') as outfile:
# 	for filepath in paths:
# 		base = os.path.basename(filepath)
# 		all_filenames.append(base)
# 	for filepath in paths:
# 		result = model.transcribe(filepath)
# 		output = result["text"].lstrip()
# 		output = output.replace("\n","")
# 		thefile = str(os.path.basename(filepath).lstrip(".")).rsplit(".")[0]
# 		outfile.write(thefile + '|' + output + '|' + output + '\n')
# 		print(thefile + '|' + output + '|' + output + '\n')


for filepath in paths:
	base = os.path.basename(filepath)
	all_filenames.append(base)

for filepath in paths:
	new_path = filepath[56:]
	if ("mic1" in new_path):
		result = model.transcribe(filepath)
		output = result["text"].lstrip()
		output = output.replace("\n","")
		thefile = new_path[0:8]
		the_id = new_path[0:4]
		with open('/content/drive/MyDrive/'+ dataset_name + '/txt/' + the_id + '/' + thefile + '.txt' , 'w', encoding='utf-8') as outfile:
			outfile.write(output + '\n')
			print(thefile + '|' + output + '\n')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-87af35f940d4> in <cell line: 1>()
# ----> 1 import whisper
#       2 import os, os.path
#       3 import glob
#       4 import pandas as pd
#       5
#
# ModuleNotFoundError: No module named 'whisper'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import os, os.path
import glob

wavs = '/content/drive/MyDrive/VCTK/wav48_silence_trimmed/p500'
paths = glob.glob(os.path.join(wavs, '*.wav'))

from pydub import AudioSegment

for z in paths:
  print(z)
  # corrected = z[55:68]
  # song = AudioSegment.from_wav(z)
  # song.export(corrected + '.flac',format = "flac")

# %%
cd ../
# Out:
# /content

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
## Convert all wav files to flac
import os, os.path
import glob

wavs = '/content/drive/MyDrive/'+ dataset_name + '/wav48_silence_trimmed/p501/'
paths = glob.glob(os.path.join(wavs, '*.wav'))

from pydub import AudioSegment

for z in paths:
  corrected = z[56:69]
  song = AudioSegment.from_wav(z)
  song.export(z[:69] + '.flac',format = "flac")
  import os
  os.remove('{}'.format(z))
